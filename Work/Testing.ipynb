# %%
import rama
import getcoordinates_andy
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from importlib import reload
import time
#%matplotlib inline
# %matplotlib notebook
# Out:
# vel : 30
# theta : 80
# r : 0.36709927
# Old Rama Eccentricity: 0.44068
# New Rama Eccentricity: 1.0

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned OFF

# %%
reload(rama)
reload(getcoordinates_andy)
# Out:
# vel : 30
# theta : 80
# r : 0.36709927
# Old Rama Eccentricity: 0.44068
# New Rama Eccentricity: 1.0
# <module 'getcoordinates_andy' from '/Users/andrewwinhold/final-rendezvous-with-ramageddon/Work/getcoordinates_andy.py'>

# %%
# based on get_Coordinates() 
tmax = 2 #units of years
dt = 0.001 #units of years
t = np.linspace(0, tmax, int(tmax/dt))

r, v = getcoordinates_andy.get_perifocal()
er, ev = getcoordinates_andy.get_heliocentric(r, v)

# %%
xt1, vt, KE, UE, TE = rama.dynamics(er, ev, dt, tmax)
# Out:
# rama initial position: [ -1.58645951e+00  -7.69500536e-01   2.05618168e-07]
# earth_pos.shape (200,)
# x.shape[:,3] (200, 3)
# Iteration: 14 , Rama distance from Earth (au): 0.00179861689426
# Iteration: 15 , Rama distance from Earth (au): 0.0482854433328
# Iteration: 34 , Rama distance from Earth (au): 0.0279619606953
# Iteration: 35 , Rama distance from Earth (au): 0.0229124871017

# %%
mpl.rcParams['legend.fontsize'] = 10

fig2 = plt.figure()
ax2 = fig2.add_subplot(111, projection='3d')
ax2.scatter(xt1[:,0,0],xt1[:,0,1],xt1[:,0,2], color='yellow', label='sun')
#ax2.scatter(xt1[0,1,0],xt1[0,1,1],xt1[0,1,2], color='black', label='mercury')

ax2.plot(xt1[:,1,0],xt1[:,1,1],xt1[:,1,2], color='black', label='mercury')
ax2.plot(xt1[:,2,0],xt1[:,2,1],xt1[:,2,2], color='green', label='venus')
ax2.plot(xt1[:,3,0],xt1[:,3,1],xt1[:,3,2], color='blue', label='earth')
ax2.plot(xt1[:,4,0],xt1[:,4,1],xt1[:,4,2], color='red', label='mars')
ax2.plot(xt1[:,5,0],xt1[:,5,1],xt1[:,5,2], color='magenta', label='jupiter')
ax2.plot(xt1[:,6,0],xt1[:,6,1],xt1[:,6,2], color='blue', label='saturn')
ax2.plot(xt1[:,7,0],xt1[:,7,1],xt1[:,7,2], color='green', label='uranus')
ax2.plot(xt1[:,8,0],xt1[:,8,1],xt1[:,8,2], color='cyan', label='neptune')
ax2.plot(xt1[:,9,0],xt1[:,9,1],xt1[:,9,2], color='orange', label='rama')
# ax2.plot(-2.52064073e-01, -9.82989588e-01,  8.26315127e-07, color='red', label='collision')
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax2.set_zlabel("z")
ax2.auto_scale_xyz([-2,2],[-2,2],[-2,2])


ax2.legend(bbox_to_anchor=(1,1), bbox_transform=plt.gcf().transFigure)
# Out:
# <img src="data:image/png;base64,...">
